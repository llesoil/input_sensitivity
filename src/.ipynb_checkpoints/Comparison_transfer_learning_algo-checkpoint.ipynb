# %% [markdown]
# # Results

# %%
import os

import pandas as pd

import numpy as np

from sklearn import preprocessing

from scipy import stats
import scipy.stats as sc
from scipy.cluster.hierarchy import linkage,leaves_list

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

from import_data import load_data

# %%
listVideo = load_data('../data_luc/video/')
    
nbVideos = len(listVideo)

def mape(y_true, y_pred):
    return np.mean(np.abs((y_true-y_pred)/y_true))
# Out:
#    configurationID  H264  no_8x8dct  no_asm  no_cabac  no_deblock  \
# 0                1  True       True   False     False        True
# 1               10  True       True   False      True       False
# 2              100  True       True   False     False        True
# 3             1000  True       True   False      True       False
# 4             1001  True      False   False     False        True
#
#    no_fast_pskip  no_mbtree  no_mixed_refs  no_weightb  rc_lookahead  ref  \
# 0           True      False           True        True            20    9
# 1           True      False          False        True            40    9
# 2          False       True           True       False            40    1
# 3           True       True           True       False            40    9
# 4          False      False           True       False            60    5
#
#       size  usertime  systemtime  elapsedtime
# 0  1718492   22.9416      0.2784       3.1876
# 1  1962957   26.8176      0.3136       4.5942
# 2  3657562   18.7344      0.2088       2.4482
# 3  3436410   24.3128      0.2744       3.4714
# 4  2066645   20.1128      0.2872       3.0110
# There are 17 videos

# %%
res_no_transfer = pd.read_csv("../data_luc/res/res_no_transfer_nb_conf_training.csv")
res_no_transfer = res_no_transfer.set_index('id_video')
nbConfig = np.array(res_no_transfer.columns, dtype=int)
res_no_transfer
# Out:
#                 16        32        64       128       256       320  \
# id_video
# 0         0.315903  0.335105  0.274581  0.175285  0.123860  0.108373
# 1         0.242384  0.276141  0.210945  0.181609  0.142979  0.129489
# 2         0.253462  0.296613  0.227474  0.158061  0.130553  0.097945
# 3         0.362272  0.325348  0.189328  0.153551  0.109045  0.095252
# 4         0.259402  0.229292  0.190534  0.153408  0.117503  0.092549
# 5         0.234331  0.257739  0.194140  0.190699  0.122641  0.104538
# 6         0.297728  0.238203  0.230293  0.136081  0.074924  0.052311
# 7         0.399790  0.270710  0.207764  0.114372  0.063635  0.049566
# 8         0.240958  0.204356  0.211082  0.115455  0.084659  0.067447
# 9         0.250620  0.265745  0.212130  0.119935  0.052049  0.041671
# 10        0.258088  0.217034  0.181871  0.159425  0.112525  0.085893
# 11        0.259885  0.230442  0.233583  0.155508  0.084252  0.084032
# 12        0.322383  0.262977  0.235581  0.189645  0.129805  0.103881
# 13        0.254359  0.239915  0.171819  0.163873  0.107651  0.110599
# 14        0.322133  0.430749  0.268692  0.216444  0.150330  0.112193
# 15        0.298950  0.271718  0.215354  0.147587  0.093519  0.083568
# 16        0.327726  0.235472  0.196327  0.134775  0.084879  0.071872
#
#                448       640       960
# id_video
# 0         0.082577  0.061107  0.043695
# 1         0.097385  0.081001  0.056462
# 2         0.089826  0.069445  0.053633
# 3         0.078965  0.066658  0.059151
# 4         0.055915  0.042847  0.031810
# 5         0.084439  0.048778  0.036180
# 6         0.048366  0.029014  0.021959
# 7         0.046428  0.032158  0.028625
# 8         0.057366  0.045624  0.034535
# 9         0.037301  0.028315  0.023424
# 10        0.055861  0.049246  0.034073
# 11        0.066644  0.040325  0.032448
# 12        0.086802  0.066794  0.044565
# 13        0.097265  0.073268  0.065353
# 14        0.070576  0.029327  0.021825
# 15        0.055305  0.042865  0.024034
# 16        0.048855  0.034270  0.025624

# %%
res_model_shift = pd.read_csv('../data_luc/res/res_model_shift_nb_conf_training.csv')
res_model_shift = res_model_shift.set_index('id_video')
res_model_shift
# Out:
#                 16        32        64       128       256       320  \
# id_video
# 0         0.312710  0.416827  0.189843  0.141220  0.129560  0.128981
# 1         0.328505  0.153304  0.104304  0.082732  0.079018  0.079200
# 2         0.252018  0.343147  0.130415  0.108172  0.104484  0.100423
# 3         0.300609  0.295016  0.121715  0.125547  0.104995  0.102928
# 4         0.269439  0.179487  0.081027  0.067047  0.057816  0.060469
# 5         0.262485  0.219838  0.104698  0.075014  0.071795  0.071217
# 6         0.282295  0.292163  0.109365  0.077924  0.070873  0.071842
# 7         0.296390  0.177827  0.100126  0.073921  0.069273  0.069830
# 8         0.230296  0.327069  0.103912  0.074791  0.073396  0.078559
# 9         0.319720  0.125989  0.121224  0.096472  0.086695  0.087571
# 10        0.299033  0.150340  0.074209  0.062711  0.059106  0.059000
# 11        0.331941  0.317891  0.098958  0.086647  0.082712  0.078744
# 12        0.232631  0.191974  0.083397  0.081781  0.074333  0.076082
# 13        0.234077  0.231690  0.138699  0.092620  0.086676  0.086288
# 14        0.437919  0.235831  0.144597  0.118059  0.112086  0.108461
# 15        0.308305  0.240658  0.088534  0.074445  0.073959  0.070516
# 16        0.268517  0.210248  0.074301  0.063600  0.058867  0.057947
#
#                448       640       960
# id_video
# 0         0.127956  0.127010  0.126667
# 1         0.074390  0.076045  0.073758
# 2         0.104150  0.099687  0.101011
# 3         0.103251  0.099997  0.101080
# 4         0.057710  0.059024  0.057457
# 5         0.071087  0.069273  0.069037
# 6         0.072115  0.070040  0.070858
# 7         0.067872  0.065425  0.067382
# 8         0.071226  0.072704  0.071556
# 9         0.088241  0.085207  0.083134
# 10        0.058438  0.058090  0.057197
# 11        0.077956  0.076661  0.077444
# 12        0.076162  0.074024  0.073587
# 13        0.084846  0.085202  0.082916
# 14        0.109821  0.109355  0.106034
# 15        0.069933  0.068002  0.067282
# 16        0.056598  0.057083  0.056708

# %%
res_full_transfer = pd.read_csv('../data_luc/res/res_full_transfer_nb_conf_training.csv')
res_full_transfer = res_full_transfer.set_index('id_video')
res_full_transfer
# Out:
#                 16        32        64       128       256       320  \
# id_video
# 0         0.312710  0.416827  0.189843  0.141220  0.129560  0.128981
# 1         0.328505  0.153304  0.104304  0.082732  0.079018  0.079200
# 2         0.252018  0.343147  0.130415  0.108172  0.104484  0.100423
# 3         0.300609  0.295016  0.121715  0.125547  0.104995  0.102928
# 4         0.269439  0.179487  0.081027  0.067047  0.057816  0.060469
# 5         0.262485  0.219838  0.104698  0.075014  0.071795  0.071217
# 6         0.282295  0.292163  0.109365  0.077924  0.070873  0.071842
# 7         0.296390  0.177827  0.100126  0.073921  0.069273  0.069830
# 8         0.230296  0.327069  0.103912  0.074791  0.073396  0.078559
# 9         0.319720  0.125989  0.121224  0.096472  0.086695  0.087571
# 10        0.299033  0.150340  0.074209  0.062711  0.059106  0.059000
# 11        0.331941  0.317891  0.098958  0.086647  0.082712  0.078744
# 12        0.232631  0.191974  0.083397  0.081781  0.074333  0.076082
# 13        0.234077  0.231690  0.138699  0.092620  0.086676  0.086288
# 14        0.437919  0.235831  0.144597  0.118059  0.112086  0.108461
# 15        0.308305  0.240658  0.088534  0.074445  0.073959  0.070516
# 16        0.268517  0.210248  0.074301  0.063600  0.058867  0.057947
#
#                448       640       960
# id_video
# 0         0.127956  0.127010  0.126667
# 1         0.074390  0.076045  0.073758
# 2         0.104150  0.099687  0.101011
# 3         0.103251  0.099997  0.101080
# 4         0.057710  0.059024  0.057457
# 5         0.071087  0.069273  0.069037
# 6         0.072115  0.070040  0.070858
# 7         0.067872  0.065425  0.067382
# 8         0.071226  0.072704  0.071556
# 9         0.088241  0.085207  0.083134
# 10        0.058438  0.058090  0.057197
# 11        0.077956  0.076661  0.077444
# 12        0.076162  0.074024  0.073587
# 13        0.084846  0.085202  0.082916
# 14        0.109821  0.109355  0.106034
# 15        0.069933  0.068002  0.067282
# 16        0.056598  0.057083  0.056708

# %%
res_full_transfer_reg = pd.read_csv('../data_luc/res/res_full_transfer_nb_conf_training_reg.csv')
res_full_transfer_reg = res_full_transfer_reg.set_index('id_video')
res_full_transfer_reg

# %% [markdown]
# # When and how to use transfer learning?

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(5,4,20)
for i in range(nbVideos):
    plt.subplot(5,4,i+1)
    plt.ylim((0,50))
    plt.ylabel('MAPE (%)')
    plt.plot(nbConfig, 100*res_no_transfer.iloc[i], 'o-', c='blue', label = 'No transfer')
    plt.plot(nbConfig, 100*res_model_shift.iloc[i], 'o-', c='red', label = 'Model shift')
    plt.plot(nbConfig, 100*res_full_transfer.iloc[i], 'o-', c='green', label = 'Full transfer')
    plt.plot(nbConfig, 100*res_full_transfer.iloc[i], 'o-', c='black', label = 'Full transfer reg')
    plt.legend()
    plt.title('Video '+str(i))
plt.show()
